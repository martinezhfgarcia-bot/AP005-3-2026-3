# %% [markdown]
# # **Dictionaries2.py**

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}
print(building_heights["Burj Khalifa"])
print(building_heights["Ping An"])

# %% [markdown]
# *Crea un diccionario con edificios y sus alturas. Luego, busca e imprime la altura específica del Burj Khalifa y del Ping An usando sus nombres como claves (keys).*

# %%
zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}
print(zodiac_elements["earth"])
print(zodiac_elements["fire"])

# %% [markdown]
# *Crea un diccionario donde las claves son elementos de la naturaleza y los valores son listas de signos zodiacales. Después, imprime en pantalla los signos que pertenecen a la tierra y al fuego.*

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}
# print(building_heights["Landmark 81"])

# %% [markdown]
# *Este ejemplo intenta buscar un edificio que no existe en el diccionario. Se deja comentado con un '#' porque ejecutar esta instrucción directamente generaría un error y detendría el programa.*

# %%
key_to_check = "Landmark 81"

if key_to_check in building_heights:
    print(building_heights["Landmark 81"])

# %% [markdown]
# *Para evitar el error del ejemplo anterior, usamos la palabra 'in' junto con un condicional (if). Esto le dice al programa que verifique primero si la clave existe antes de intentar imprimirla.*

# %%
zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

zodiac_elements["energy"] = "Not a Zodiac element"

if "energy" in zodiac_elements:
    print(zodiac_elements["energy"])
# Out:
# Not a Zodiac element

# %% [markdown]
# *Agrega una nueva clave inventada ("energy") al diccionario del zodiaco y luego verifica con un condicional si se guardó correctamente antes de imprimir su mensaje.*

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

print(building_heights.get("Shanghai Tower"))
print(building_heights.get("My House"))

# %% [markdown]
# *Muestra una forma más profesional de buscar datos usando la función .get(). Si el elemento existe muestra su valor, pero si no existe (como "My House") devuelve la palabra 'None' (nada) en lugar de lanzar un error.*

# %%
user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

if user_ids.get("teraCoder") == None:
    tc_id = 1000
else:
    tc_id = user_ids.get("teraCoder")

print(tc_id)

# %% [markdown]
# *Usa .get() en un condicional para revisar un ID. Si el usuario no tiene ID (devuelve None), le asigna 1000 por defecto. Como "teraCoder" sí existe, extrae y muestra su número real (100019).*

# %%
if user_ids.get("superStackSmash") == None:
     stack_id = 100000

print(stack_id)

# %% [markdown]
# *Busca al usuario "superStackSmash". Como no está en el diccionario, la función .get() devuelve 'None' y el programa le asigna el número 100000 de forma automática.*

# %%
raffle = {223842: "Teddy Bear", 872921: "Concert Tickets", 320291: "Gift Basket", 412123: "Necklace", 298787: "Pasta Maker"}
print(raffle.pop(320291, "No Prize"))
print(raffle)

# %% [markdown]
# *Usa la función .pop() para buscar y sacar un premio de la rifa (el 320291). Imprime el premio extraído y luego muestra el diccionario para confirmar que ese premio ya no está disponible.*

# %%
print(raffle.pop(100000, "No Prize"))
print(raffle)

# %% [markdown]
# *Intenta extraer el número de boleto 100000 con .pop(). Como no existe, devuelve el mensaje de protección "No Prize" sin borrar nada del diccionario principal.*

# %%
print(raffle.pop(872921, "No Prize"))
print(raffle)

# %% [markdown]
# *Saca y muestra el premio ganador de las entradas al concierto. Luego imprime el diccionario para comprobar que ese premio también desapareció de la lista.*

# %%
available_items = {"health potion": 10, "cake of the cure": 5, "green elixir": 20, "strength sandwich": 25, "stamina grains": 15, "power stew": 30}
health_points = 20

health_points += available_items.pop("stamina grains", 0)
health_points += available_items.pop("power stew", 0)
health_points += available_items.pop("mystic bread", 0)

print(available_items)
print(health_points)

# %% [markdown]
# *Simula el inventario de un videojuego. Usa .pop() para consumir comida, borrándola del inventario y sumando sus puntos a la salud total. Si un objeto no existe (como el pan místico), suma 0 para no alterar el juego.*

# %%
test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}
print(list(test_scores))

# %% [markdown]
# *Crea un diccionario con calificaciones y usa la función list() para extraer únicamente los nombres (las claves) y mostrarlos en formato de lista de texto.*

# %%
for student in test_scores.keys():
    print(student)

# %% [markdown]
# *Utiliza un ciclo 'for' junto con la función .keys() para recorrer el diccionario y mostrar en la pantalla los nombres de los estudiantes uno por uno hacia abajo.*

# %%
user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}
num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

users = user_ids.keys()
lessons = num_exercises.keys()

print(users)
print(lessons)

# %% [markdown]
# *Usa .keys() para agrupar todas las claves de dos diccionarios distintos, guardándolas en variables nuevas (users y lessons) que luego se imprimen por separado.*

# %%
test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

for score_list in test_scores.values():
    print(score_list)

# %% [markdown]
# *Usa un ciclo 'for' junto con .values() para recorrer el diccionario, pero esta vez ignora los nombres y muestra únicamente las listas de las calificaciones de cada persona.*

# %%
num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

total_exercises = 0

for exercises in num_exercises.values():
    total_exercises += exercises

print(total_exercises)

# %% [markdown]
# *Crea un contador desde cero. Utiliza el ciclo 'for' con .values() para extraer todos los números del diccionario e irlos sumando poco a poco. Al terminar, imprime el gran total de ejercicios (115).*

# %%
biggest_brands = {"Apple": 184, "Google": 141.7, "Microsoft": 80, "Coca-Cola": 69.7, "Amazon": 64.8}

for company, value in biggest_brands.items():
    print(company + " has a value of " + str(value) + " billion dollars. ")

# %% [markdown]
# *La función .items() extrae ambas cosas al mismo tiempo (clave y valor). El ciclo recorre cada marca junto con su valor para armar y mostrar una oración completa por cada empresa.*

# %%
pct_women_in_occupation = {"CEO": 28, "Engineering Manager": 9, "Pharmacist": 58, "Physician": 40, "Lawyer": 37, "Aerospace Engineer": 9}

for occupation, percentage in pct_women_in_occupation.items():
    print("Women make up " + str(percentage) + " percent of " + occupation + "s.")

# %% [markdown]
# *Igual que en el bloque anterior, utiliza .items() para recorrer los cargos y sus porcentajes en pareja, integrándolos en una oración que se imprime línea por línea.*
