# %% [markdown]
# # **15. UDMY**

# %%
nba.sort_values(["Team", "Name"], na_position = "first", inplace = True)

# %% [markdown]
# * *nba.sort_values(["Team", "Name"]): Ordena el DataFrame jerárquicamente priorizando el equipo y luego el nombre.*
#
# * *na_position = "first": Obliga a que cualquier valor nulo (NaN) aparezca en la parte superior de la tabla.*
#
# * *inplace = True: Guarda los cambios de forma permanente en la memoria del DataFrame original.*

# %%
nba.sort_index()

# %% [markdown]
# *Vuelve a ordenar el DataFrame tomando como referencia estricta las etiquetas numéricas originales del índice, deshaciendo los cambios de ordenamientos previos.*
