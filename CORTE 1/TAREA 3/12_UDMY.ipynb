# %% [markdown]
# # **12. UDMY**

# %%
nba["Salary"]

# %% [markdown]
# *Extrae y muestra únicamente la columna "Salary", devolviendo una estructura de datos unidimensional (Serie) en lugar de toda la tabla.*

# %%
nba["Salary"].add(50000)

# %% [markdown]
# *Utiliza el método nativo .add() de Pandas para sumar 50,000 a cada uno de los valores numéricos dentro de la columna de salarios.*

# %%
nba["Salary"] + 2000000

# %% [markdown]
# *Realiza la misma operación de suma a todos los registros, pero utilizando el operador matemático estándar + de Python en lugar del método de Pandas.*

# %%
nba["bonus_salary"] = nba["Salary"] + 30000

# %% [markdown]
# *Crea una columna completamente nueva llamada bonus_salary y la añade al final del DataFrame. Su valor se calcula tomando el salario original de cada jugador y sumándole 30,000.*

# %%
nba["Salary"].sub(55000)

# %% [markdown]
# *Emplea el método .sub() para restar 55,000 a todos los valores de la columna "Salary".*

# %%
  nba["Salary"].div(1000000)

# %% [markdown]
# *Utiliza el método .div() para dividir los salarios entre 1,000,000, una técnica muy útil para expresar cifras monetarias grandes en formato de millones.*

# %%
nba["Weight"].mul(0.453592)

# %% [markdown]
# *Aplica el método .mul() para multiplicar la columna "Weight" por 0.453592, lo que efectúa una conversión directa del peso (por ejemplo, pasando de libras a kilogramos).*
