# %% [markdown]
# # **1. UDMY**

# %% [markdown]
# # Análisis de Casos COVID-19 en Nueva York
# *En este ejercicio aprenderemos a importar bases de datos desde internet y exportarlas en diferentes formatos.*

# %%
import pandas as pd

# %% [markdown]
# *Importa la librería pandas, la cual es la herramienta principal en Python para el análisis y manipulación de datos.*

# %%
url = "https://data.cityofnewyork.us/resource/rc75-m7u3.csv"

# %% [markdown]
# *Crea una variable llamada 'url' para almacenar el enlace web directo donde se encuentra nuestro archivo original.*

# %%
covid = pd.read_csv(url)

# %% [markdown]
# *Usa la función read_csv de pandas para leer el archivo desde internet.
# Al mismo tiempo, convierte esa información en una tabla de datos (DataFrame) llamada 'covid'.*

# %%
covid.head()

# %% [markdown]
# *Muestra en pantalla las primeras cinco filas de la tabla.
# Esto nos sirve para dar un vistazo rápido y comprobar que los datos cargaron correctamente sin ver todo el archivo.*

# %%
covid.info()

# %% [markdown]
# *Imprime un resumen técnico completo de la tabla.
# Nos muestra cuántas columnas hay, sus nombres, el tipo de dato que guardan (números o texto) y si faltan datos en alguna celda.*

# %%
covid.to_csv('NYC_covid_cases.csv')

# %% [markdown]
# *Toma la tabla que está en la memoria temporal de Colab y la exporta.
# Crea un archivo físico llamado 'NYC_covid_cases.csv' guardando toda la información.*

# %%
covid.to_csv('NYC1_covid_cases.csv', columns = ['case_count', 'hospitalized_count', 'death_count'])

# %% [markdown]
# *Exporta un nuevo archivo CSV a nuestro entorno.
# Esta vez utiliza el parámetro 'columns' para filtrar y guardar únicamente las columnas de contagios, hospitalizados y muertes.*
