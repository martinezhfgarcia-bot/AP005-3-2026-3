# %% [markdown]
# # **9. UDMY**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# * *from google.colab import drive: Importa el módulo específico de Colab para interactuar con los servicios de Google.*
# * *drive.mount('/content/drive'): Conecta y monta tu unidad de Google Drive en el entorno virtual, otorgando los permisos necesarios para acceder a tus archivos guardados.*

# %%
import pandas as pd
nba = pd.read_excel('/content/drive/MyDrive/udmy/dataAnalisys/Nba Teams.xlsx')

# %% [markdown]
# * *import pandas as pd: Importa Pandas, la librería principal para análisis y manipulación de datos, y le asigna el alias pd.*
#
# * *nba = pd.read_excel(...): Lee el archivo Excel desde la ruta especificada en Drive y carga toda la tabla de datos en una variable principal llamada nba.*

# %%
nba.head(10)

# %% [markdown]
# *Muestra las primeras 10 filas de la tabla para dar un vistazo rápido a la estructura y contenido inicial de los datos cargados.*

# %%
nba.info()

# %% [markdown]
# *Imprime un resumen técnico del DataFrame. Muestra el total de filas, el nombre de las columnas, la cantidad de valores no nulos y el tipo de dato de cada una.*

# %%
nba.isnull().sum()

# %% [markdown]
# *  *nba.isnull(): Evalúa cada celda de la tabla y marca como Verdadero (True) aquellas que están vacías o son nulas (NaN).*
#
# * *.sum(): Suma todos los valores verdaderos por columna, mostrando exactamente cuántos datos faltan en cada variable.*

# %%
nba.tail()

# %% [markdown]
# *Muestra por defecto las últimas 5 filas del DataFrame para verificar cómo termina la estructura de la tabla.*
