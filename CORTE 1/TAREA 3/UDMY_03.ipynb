# %% [markdown]
# # **3. udmy3_Dataframe_from_Dictionary**

# %% [markdown]
# # Importación y Exploración de Archivos Excel
# *En este ejercicio cargaremos una base de datos externa de la NBA en formato Excel y analizaremos su estructura.*

# %%
import pandas as pd
nba = pd.read_excel('Nba Teams.xlsx')
nba

# %% [markdown]
# *Importa la librería pandas para manipular datos.
# Utiliza la función '.read_excel()' para cargar el archivo físico 'Nba Teams.xlsx' en la variable 'nba'.
# Escribir el nombre de la variable al final permite que Colab imprima la tabla completa en pantalla.*

# %%
nba.info()

# %% [markdown]
# *Aplica la función '.info()' sobre la tabla para obtener un resumen técnico.
# Esto revela el número total de filas, columnas, el tipo de dato de cada una y si existen casillas vacías (nulos).*

# %%
nba.head()

# %% [markdown]
# *Usa la función '.head()' para mostrar únicamente las primeras cinco filas de la tabla.
# Es ideal para inspeccionar los datos rápidamente sin saturar la pantalla.*

# %%
nba.head(5).info()

# %% [markdown]
# *Combina dos funciones en una sola línea de código.
# Primero extrae las cinco filas iniciales con '.head(5)' y luego le aplica '.info()' para analizar exclusivamente ese pequeño fragmento.*
