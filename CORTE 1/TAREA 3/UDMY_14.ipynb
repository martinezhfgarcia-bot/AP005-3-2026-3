# %% [markdown]
# # **14. UDMY**
#
# *(Conteo de Frecuencias)
# Conteo básico de valores únicos*

# %%
nba["Team"].value_counts()

# %% [markdown]
# *Toma la columna específica "Team" y cuenta exactamente cuántas veces se repite cada valor único dentro de ella (en este caso, cuántos jugadores hay registrados en cada equipo de baloncesto). Por defecto, devuelve una lista ordenada de mayor a menor frecuencia.*

# %%
  #nba["Division"].value_counts()
nba["Division"].value_counts(ascending = True)

# %% [markdown]
# * *nba["Division"].value_counts(...): Ejecuta el conteo de repeticiones, pero esta vez aplicado a las categorías de la columna "Division".*
#
# * *(ascending = True): Modifica el comportamiento predeterminado de la función, forzando a que los resultados del conteo se muestren ordenados de menor a mayor cantidad (mostrando primero la división con la menor cantidad de registros).*
