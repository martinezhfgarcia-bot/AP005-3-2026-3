# %% [markdown]
# # **16_1. UDMY**

# %%
emp.info()

# %% [markdown]
# *Muestra un reporte detallado del DataFrame, incluyendo el total de registros (1010), las columnas existentes, el conteo de valores no nulos, los tipos de datos y el consumo total de memoria del sistema.*

# %%
emp.nunique()

# %% [markdown]
# *Calcula y devuelve el número exacto de valores únicos contenidos en cada una de las columnas del DataFrame.*

# %%
emp[["department", "position"]] = emp[["department", "position"]].astype("category")

# %% [markdown]
# * *emp[["department", "position"]]: Selecciona las columnas de departamentos y posiciones.*
#
# * *.astype("category"): Convierte el tipo de datos de texto genérico a tipo categoría, lo que reduce drásticamente el uso de memoria RAM en Pandas.*

# %%
"happy".upper()
"PYTHON".lower()

# %% [markdown]
# * *Demuestran el funcionamiento básico de los métodos de cadenas para convertir texto a mayúsculas (upper()) o minúsculas (lower()) de manera individual.*

# %%
emp["name"].str.lower().str.title()

# %% [markdown]
# * *emp["name"].str: Habilita el acceso a los métodos de manipulación de texto de Pandas para aplicarlos masivamente a toda una columna.*
#
# * *.lower().str.title(): Convierte primero los caracteres a minúsculas y luego aplica el formato de título (primera letra de cada palabra en mayúscula) a todos los registros.*
